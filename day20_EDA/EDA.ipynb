# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('titanic_train.csv')

# %%
df.sample(1)
# Out:
#      PassengerId  Survived  Pclass                    Name   Sex   Age  SibSp  \
# 292          293         0       2  Levy, Mr. Rene Jacques  male  36.0      0
#
#      Parch         Ticket    Fare Cabin Embarked
# 292      0  SC/Paris 2163  12.875     D        C

# %% [markdown]
# for categirical data analysis

# %% [markdown]
# #a.countplot

# %%
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
df['Embarked'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Embarked'>

# %%
sns.countplot(x = 'Sex' , data = df )
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
df['Embarked'].value_counts().plot(kind = 'pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Pclass'].value_counts().plot(kind = 'pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Numerical dataa analaysis

# %% [markdown]
# a.Histogram

# %%
sns.histplot(df['Fare'],bins = 15 , color='skyblue', edgecolor='black',kde = True, )
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
sns.histplot(df['Age'],bins = 15 , color='skyblue', edgecolor='black', log=False,kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# Boxplot

# %%
sns.boxplot(x = 'Age' , data = df )
# Out:
# <Axes: xlabel='Age'>

# %%
sns.boxplot(x = 'Fare' , data = df )
# Out:
# <Axes: xlabel='Fare'>
