# %%
import pandas as pd

# %% [markdown]
# ## json file

# %% [markdown]
# #link for documentation

# %%
#https://www.youtube.com/redirect?event=video_description&redir_token=QUFFLUhqbVVRTHRHMVdLeVpmLWhjY0JPWHUxcjRSZzZod3xBQ3Jtc0ttdFdQUHlvdk1WbnpJZE9BRG5yNzVvSUVodTlOUEJyVUpVd0gyV3RuSlljcWpUeDlia3owVHdLbzkyLWFuUzlMeW1HYjVmT2Y5ekVhTFR5NG9rNFVNYV9BaVhBc05EbWZfTGhVYWRhcXhISUhNZUEtZw&q=https%3A%2F%2Fpandas.pydata.org%2Fdocs%2Freference%2Fapi%2Fpandas.read_json.html&v=fFwRC-fapIU

# %%
pd.read_json('train.json')
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %% [markdown]
# #we can pass any active link in the place of file address

# %%
df = pd.read_json('https://storage.googleapis.com/kagglesdsdata/datasets/5791540/9513866/spongebob_characters.json?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20250927%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20250927T174921Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...')

# %%
df
# Out:
#                            name  \
# 0               French Narrator
# 1                    Sea urchin
# 2     Garold "Gary" Wilson, Jr.
# 3                       Shelley
# 4                  Patrick Star
# ...                         ...
# 2420           Sammy Suckerfish
# 2421                      Moppy
# 2422                     Turtle
# 2423         Restaurant manager
# 2424              Incidental 95
#
#                                                    info  \
# 0     {'Residence': 'His submarine', 'Occupation(s)'...
# 1     {'Types': 'Big and small', 'Colors': 'Brown an...
# 2     {'Residence': ['Animal shelter, Bikini Bottom,...
# 3     {'Residence': '124 Conch Street, Bikini Bottom...
# 4     {'Residence': ['Star house, Bikini Bottom, Pac...
# ...                                                 ...
# 2420  {'Residence': 'Bikini Bottom, Pacific Ocean', ...
# 2421  {'Residence': 'Bikini Bottom, Pacific Ocean', ...
# 2422  {'Residence': 'Bikini Bottom, Pacific Ocean', ...
# ...
