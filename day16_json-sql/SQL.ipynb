# %%
#!pip install mysql.connector
import pandas as pd

# %%
import mysql.connector

# %%
con = mysql.connector.connect(host = 'localhost', user = 'root' , password = '',database = 'world')

# %%
#pd.read_sql_query("SELECT * FROM city WHERE CountryCode LIKE 'IND' ",con)

# %%
pd.read_sql_query("SELECT * FROM country WHERE Population < 10000000 ",con)
# Out:
# C:\Users\navee\AppData\Local\Temp\ipykernel_5788\4277865023.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM country WHERE Population < 10000000 ",con)
#     Code                  Name      Continent           Region  SurfaceArea  \
# 0    ABW                 Aruba  North America        Caribbean        193.0
# 1    AIA              Anguilla  North America        Caribbean         96.0
# 2    ALB               Albania         Europe  Southern Europe      28748.0
# 3    AND               Andorra         Europe  Southern Europe        468.0
# 4    ANT  Netherlands Antilles  North America        Caribbean        800.0
# ..   ...                   ...            ...              ...          ...
# 156  VIR  Virgin Islands, U.S.  North America        Caribbean        347.0
# 157  VUT               Vanuatu        Oceania        Melanesia      12189.0
# 158  WLF     Wallis and Futuna        Oceania        Polynesia        200.0
# 159  WSM                 Samoa        Oceania        Polynesia       2831.0
# 160  ZMB                Zambia         Africa   Eastern Africa     752618.0
#
#      IndepYear  Population  LifeExpectancy     GNP  GNPOld  \
# 0          NaN      103000            78.4   828.0   793.0
# 1          NaN        8000            76.1    63.2     NaN
# 2       1912.0     3401200            71.6  3205.0  2500.0
# 3       1278.0       78000            83.5  1630.0     NaN
# 4          NaN      217000            74.7  1941.0     NaN
# ..         ...         ...             ...     ...     ...
# 156        NaN       93000            78.1     0.0     NaN
# 157     1980.0      190000            60.6   261.0   246.0
# 158        NaN       15000             NaN     0.0     NaN
# 159     1962.0      180000            69.2   141.0   157.0
# 160     1964.0     9169000            37.2  3377.0  3922.0
#
#                                LocalName  \
# 0                                  Aruba
# 1                               Anguilla
# 2                              Shqipëria
# 3                                Andorra
# 4                   Nederlandse Antillen
# ..                                   ...
# 156  Virgin Islands of the United States
# 157                              Vanuatu
# 158                     Wallis-et-Futuna
# 159                                Samoa
# 160                               Zambia
#
#                                    GovernmentForm             HeadOfState  \
# 0    Nonmetropolitan Territory of The Netherlands                 Beatrix
# 1                   Dependent Territory of the UK            Elisabeth II
# 2                                        Republic          Rexhep Mejdani
# 3                    Parliamentary Coprincipality
# 4    Nonmetropolitan Territory of The Netherlands                 Beatrix
# ..                                            ...                     ...
# 156                                  US Territory          George W. Bush
# 157                                      Republic               John Bani
# 158           Nonmetropolitan Territory of France          Jacques Chirac
# 159                         Parlementary Monarchy  Malietoa Tanumafili II
# 160                                      Republic       Frederick Chiluba
#
#      Capital Code2
# 0      129.0    AW
# 1       62.0    AI
# 2       34.0    AL
# 3       55.0    AD
# 4       33.0    AN
# ..       ...   ...
# 156   4067.0    VI
# 157   3537.0    VU
# 158   3536.0    WF
# 159   3169.0    WS
# 160   3162.0    ZM
#
# [161 rows x 15 columns]
