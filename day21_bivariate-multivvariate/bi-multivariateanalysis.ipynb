# %%
#important libreries
import pandas as pd
import seaborn as sns

# %%
titanic = pd.read_csv('titanic_train.csv')

# %%
#load dataset form seaborn
tips = sns.load_dataset('tips')
flights = sns.load_dataset('flights')
iris = sns.load_dataset('iris')

# %%
titanic.sample(1)
#C-> Survived[1,0] , Pclass[1,2,3] , Sex[male, female] ,SibSp , Parch, Embarked 
#N -> Age , Fare
# Out:
#      PassengerId  Survived  Pclass                Name   Sex   Age  SibSp  \
# 555          556         0       1  Wright, Mr. George  male  62.0      0
#
#      Parch  Ticket   Fare Cabin Embarked
# 555      0  113807  26.55   NaN        S

# %%
tips.sample(1)
# C-> sex , smoker , day , time ,size 
#N-> tatel_bill , tip
# Out:
#      total_bill  tip   sex smoker  day    time  size
# 167       31.71  4.5  Male     No  Sun  Dinner     4

# %%
iris.sample(1)
#N -> S_lenght , S_width , p_length , P_width
#C-> species
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 76           6.8          2.8           4.8          1.4  versicolor

# %%
flights.sample(1)
#C-> year , month 
#N->passengers
# Out:
#     year month  passengers
# 75  1955   Apr         269

# %% [markdown]
# types of plots we have
# 1. Scatterplot lib->Seaborn
#    btw -> Numeric*Numeric
#    As filter we can use categorical data hue,style,size
#
# 2. Bar plot lib->Seaborn
#    btw -> Categorical(x)*Numeric(y)
#    as filter we can use categorica data hue(p)
#
# 4. Box plot lib->Seaborn(use to detect out-liers)
#    btw -> Categorical(x)*Numeric(y)
#    as filter we can use categorica data hue(p)
#
# 5. Histplot plot
#
# 6. Heat Map lib -> Seaborn
#    btw -> Categorical*Categorical
#    lib.heatmap(pd.crosstab(col1,col2))
#
# 7. Cluster Map lib -> Seaborn
#    btw -> Categorical*Categorical
#    lib.clustermap(pd.crosstab(col1,col2))
#
# 8. Pair Plot lib -> Seaborn
#    plot scatter plot between all the numeric columes present      in the data set as we can use categorical data as filter
#    lib.pairplot(dataset ,hue='filter')
#
#
#    crosstab and pivottable
#    flights(df).pivot_table(values='passengers', index='month', columns='year', observed=False)
#    pd.crosstab(df['Category1'], df['Category2'])

# %%
tips.sample(1)
# Out:
#      total_bill  tip   sex smoker  day    time  size
# 184       40.55  3.0  Male    Yes  Sun  Dinner     2

# %%
sns.boxplot(data=tips , x = 'sex' , y = 'tip', hue= 'day')
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips, hue = 'size', style = 'sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
iris.sample(1)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 92           5.8          2.6           4.0          1.2  versicolor

# %%
sns.scatterplot(data= iris ,x='petal_length',y='petal_width',hue='species')
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
sns.pairplot(data= iris , hue = 'species')

# %%
titanic.sample(1)
# Out:
#      PassengerId  Survived  Pclass                   Name   Sex  Age  SibSp  \
# 154          155         0       3  Olsen, Mr. Ole Martin  male  NaN      0
#
#      Parch     Ticket    Fare Cabin Embarked
# 154      0  Fa 265302  7.3125   NaN        S

# %%
sns.barplot(data = titanic , x = 'Embarked' , y = 'Fare' ,hue = 'Survived' )
# Out:
# <Axes: xlabel='Embarked', ylabel='Fare'>

# %%
sns.distplot(titanic[titanic['Survived']==0]['Age'],hist=False,color='red')
sns.distplot(titanic[titanic['Survived']==1]['Age'],hist=False)
# Out:
# C:\Users\navee\AppData\Local\Temp\ipykernel_25064\3345630932.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic['Survived']==0]['Age'],hist=False,color='red')
# C:\Users\navee\AppData\Local\Temp\ipykernel_25064\3345630932.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
titanic.sample(1)
# Out:
#      PassengerId  Survived  Pclass             Name   Sex   Age  SibSp  Parch  \
# 157          158         0       3  Corn, Mr. Harry  male  30.0      0      0
#
#               Ticket  Fare Cabin Embarked
# 157  SOTON/OQ 392090  8.05   NaN        S

# %%
pd.crosstab(titanic['Pclass'],titanic['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sns.heatmap(pd.crosstab(titanic['Pclass'],titanic['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
(titanic.groupby('Embarked')['Survived'].mean()*100)
# Out:
# Embarked
# C    55.357143
# Q    38.961039
# S    33.695652
# Name: Survived, dtype: float64

# %%
sns.clustermap(pd.crosstab(titanic['Pclass'],titanic['Survived']))

# %%
flights.sample(1)
# Out:
#      year month  passengers
# 143  1960   Dec         432

# %%
new = flights.groupby('year')['passengers'].sum().reset_index()

# %%
new
# Out:
#     year  passengers
# 0   1949        1520
# 1   1950        1676
# 2   1951        2042
# 3   1952        2364
# 4   1953        2700
# 5   1954        2867
# 6   1955        3408
# 7   1956        3939
# 8   1957        4421
# 9   1958        4572
# 10  1959        5140
# 11  1960        5714

# %%
sns.lineplot(data= flights ,y = 'passengers' , x= 'month')
# Out:
# <Axes: xlabel='month', ylabel='passengers'>

# %%
sns.clustermap(flights.pivot_table(values='passengers',index='month',columns='year'))
# Out:
# C:\Users\navee\AppData\Local\Temp\ipykernel_25064\1868718285.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   sns.clustermap(flights.pivot_table(values='passengers',index='month',columns='year'))

# %%
sns.heatmap(flights.pivot_table(values='passengers',index='month',columns='year'))
# Out:
# C:\Users\navee\AppData\Local\Temp\ipykernel_25064\2230379170.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   sns.heatmap(flights.pivot_table(values='passengers',index='month',columns='year'))
# <Axes: xlabel='year', ylabel='month'>

# %%
flights.pivot_table(values='passengers', index='month', columns='year', observed=False)
# Out:
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# Aug    148.0  170.0  199.0  242.0  272.0  293.0  347.0  405.0  467.0  505.0
# Sep    136.0  158.0  184.0  209.0  237.0  259.0  312.0  355.0  404.0  404.0
# Oct    119.0  133.0  162.0  191.0  211.0  229.0  274.0  306.0  347.0  359.0
# Nov    104.0  114.0  146.0  172.0  180.0  203.0  237.0  271.0  305.0  310.0
# ...
